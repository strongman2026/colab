# %% [markdown]
# <a href="https://colab.research.google.com/github/strongman2026/colab/blob/copilot%2Foptimize-comfyui-colab/comfyui_colab_6_0329.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 诊断专用：强制重新拉取 ComfyUI 并显示真实的目录结构与报错
import os

print("🛑 1. 先清理残留进程...")
os.system("pkill -f 'main.py'")

print("\n📁 2. 检查当前 /content 目录下的文件：")
# !ls -la /content

print("\n🗑️ 3. 强制删除可能损坏的 ComfyUI 文件夹...")
# !rm -rf /content/ComfyUI

print("\n⬇️ 4. 开始显式克隆 ComfyUI (取消静默模式，显示真实报错)：")
# !git clone https://github.com/comfyanonymous/ComfyUI.git /content/ComfyUI

print("\n📦 5. 正在强制安装全部环境依赖 (显示进度)...")
# !cd /content/ComfyUI && pip install -r requirements.txt

print("\n🔍 6. 正在前台试运行 ComfyUI...")
# !cd /content/ComfyUI && python3 main.py
# Out:
# 🛑 1. 先清理残留进程...
#
# 📁 2. 检查当前 /content 目录下的文件：
# total 32
# drwxr-xr-x  1 root root 4096 Mar 28 14:29 .
# drwxr-xr-x  1 root root 4096 Mar 28 12:30 ..
# drwxr-xr-x 26 root root 4096 Mar 28 14:44 ComfyUI
# drwxr-xr-x  4 root root 4096 Mar 23 13:34 .config
# drwxr-xr-x  3 root root 4096 Mar 28 14:13 dataset
# drwx------  5 root root 4096 Mar 28 13:21 drive
# drwxr-xr-x  2 root root 4096 Mar 28 13:21 frp
# drwxr-xr-x  1 root root 4096 Mar 23 13:34 sample_data
#
# 🗑️ 3. 强制删除可能损坏的 ComfyUI 文件夹...
#
# ⬇️ 4. 开始显式克隆 ComfyUI (取消静默模式，显示真实报错)：
# Cloning into '/content/ComfyUI'...
# remote: Enumerating objects: 35547, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 35547 (delta 128), reused 66 (delta 64), pack-reused 35366 (from 2)
# Receiving objects: 100% (35547/35547), 84.05 MiB | 27.31 MiB/s, done.
# Resolving deltas: 100% (24073/24073), done.
#
# 📦 5. 正在强制安装全部环境依赖 (显示进度)...
# Requirement already satisfied: comfyui-frontend-package==1.42.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.42.8)
# Requirement already satisfied: comfyui-workflow-templates==0.9.39 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.9.39)
# Requirement already satisfied: comfyui-embedded-docs==0.4.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.10.0+cu128)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.25.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (5.0.0)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.2.1)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.13.3)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (1.18.4)
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (2.0.48)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.25.2)
# Requirement already satisfied: av>=14.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (17.0.0)
# Requirement already satisfied: comfy-kitchen>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (0.2.8)
# Requirement already satisfied: comfy-aimdo>=0.2.12 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.2.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (2.32.4)
# Requirement already satisfied: simpleeval>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (1.0.7)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (1.0.8)
# Requirement already satisfied: kornia>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 32)) (0.8.2)
# Requirement already satisfied: spandrel in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (0.4.2)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (2.12.3)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (2.13.1)
# Requirement already satisfied: PyOpenGL in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (3.1.10)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: comfyui-workflow-templates-core==0.3.188 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r requirements.txt (line 2)) (0.3.188)
# Requirement already satisfied: comfyui-workflow-templates-media-api==0.3.68 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r requirements.txt (line 2)) (0.3.68)
# Requirement already satisfied: comfyui-workflow-templates-media-video==0.3.68 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r requirements.txt (line 2)) (0.3.68)
# Requirement already satisfied: comfyui-workflow-templates-media-image==0.3.114 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r requirements.txt (line 2)) (0.3.114)
# Requirement already satisfied: comfyui-workflow-templates-media-other==0.3.161 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r requirements.txt (line 2)) (0.3.161)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from torchsde->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (26.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r requirements.txt (line 10)) (0.24.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.4.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.11)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->-r requirements.txt (line 21)) (1.3.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy->-r requirements.txt (line 22)) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 27)) (2026.2.25)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia>=0.7.1->-r requirements.txt (line 32)) (0.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->-r requirements.txt (line 35)) (1.2.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.24.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r requirements.txt (line 10)) (0.1.2)
#
# 🔍 6. 正在前台试运行 ComfyUI...
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_mxfp8', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_mxfp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_mxfp8', 'scaled_mm_nvfp4']}
# Checkpoint files will always be loaded safely.
# Total VRAM 22563 MB, total RAM 54229 MB
# pytorch version: 2.10.0+cu128
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 NVIDIA L4 : cudaMallocAsync
# Using async weight offloading with 2 streams
# Enabled pinned memory 51517.0
# working around nvidia conv3d memory bug.
# Using pytorch attention
# aimdo: src/control.c:68:INFO:comfy-aimdo inited for GPU: NVIDIA L4 (VRAM: 22563 MB)
# DynamicVRAM support detected and enabled
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ComfyUI version: 0.18.1
# comfy-aimdo version: 0.2.12
# comfy-kitchen version: 0.2.8
# ****** User settings have been changed to be stored on the server instead of browser storage. ******
# ****** For multi-user setups add the --multi-user CLI argument to enable multiple user profiles. ******
# ComfyUI frontend version: 1.42.8
# [Prompt Server] web root: /usr/local/lib/python3.12/dist-packages/comfyui_frontend_package/static
# Asset seeder disabled
#
# Import times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/websocket_image_save.py
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# Running upgrade  -> 0001_assets, Initial assets schema
# Revision ID: 0001_assets
# Revises: None
# Create Date: 2025-12-10 00:00:00
# Running upgrade 0001_assets -> 0002_merge_to_asset_references, Merge AssetInfo and AssetCacheState into unified asset_references table.
# Running upgrade 0002_merge_to_asset_references -> 0003_add_metadata_job_id, Add system_metadata and job_id columns to asset_references.
# Change preview_id FK from assets.id to asset_references.id.
# Database upgraded from None to 0003_add_metadata_job_id
# Starting server
#
# To see the GUI go to: http://127.0.0.1:8188
# Traceback (most recent call last):
#   File "/content/ComfyUI/main.py", line 526, in <module>
#     event_loop.run_until_complete(x)
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 678, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1961, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/ComfyUI/main.py", line 528, in <module>
#     logging.info("\nStopped server")
#   File "/usr/lib/python3.12/logging/__init__.py", line 2216, in info
#     root.info(msg, *args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.12/logging/__init__.py", line 1672, in _log
#     fn, lno, func, sinfo = self.findCaller(stack_info, stacklevel)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 1632, in findCaller
#     if not _is_internal_frame(f):
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 202, in _is_internal_frame
#     filename = os.path.normcase(frame.f_code.co_filename)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 52, in normcase
# KeyboardInterrupt

# %%
# cell 1:基础环境与网盘挂载（开机跑一次，完美完整版）
import os, sys, subprocess
from google.colab import drive

print("☁️ 1. 正在挂载 Google Drive (弹窗请点击允许)...")
drive.mount('/content/drive')

COMFY_DIR = "/content/ComfyUI"
FRP_DIR = "/content/frp"
FRPC_BIN = f"{FRP_DIR}/frpc"

# ================= 🚨 必填配置 =================
VPS_IP = "34.153.197.18"  # 你的服务器 IP
FRP_TOKEN = "Kaggle2026!" # 你的服务器密码
# ===============================================

print("\n📥 2. 检查并部署 ComfyUI 核心与管理器...")
# 自动纠错：如果存在文件夹但缺少核心文件，说明下载损坏，直接干掉
if os.path.exists(COMFY_DIR) and not os.path.exists(f"{COMFY_DIR}/main.py"):
    print("⚠️ 检测到损坏的 ComfyUI 文件夹，正在自动清理...")
    os.system(f"rm -rf {COMFY_DIR}")

if not os.path.exists(COMFY_DIR):
    print("⬇️ 开始克隆 ComfyUI (显示进度)...")
    # !git clone https://github.com/comfyanonymous/ComfyUI.git {COMFY_DIR}
    # !git clone https://github.com/ltdrdata/ComfyUI-Manager.git {COMFY_DIR}/custom_nodes/ComfyUI-Manager
else:
    print("✅ ComfyUI 核心代码已存在。")

print("\n📦 3. 安装环境依赖 (取消静默，确保安装成功)...")
if os.path.exists(f"{COMFY_DIR}/requirements.txt"):
    # !pip install -r {COMFY_DIR}/requirements.txt

print("\n🔧 4. 部署 FRP 客户端与配置文件...")
if not os.path.exists(FRPC_BIN):
    os.makedirs(FRP_DIR, exist_ok=True)
    os.system(f"wget -q -O {FRP_DIR}/frp.tar.gz https://github.com/fatedier/frp/releases/download/v0.61.1/frp_0.61.1_linux_amd64.tar.gz")
    os.system(f"tar -xzf {FRP_DIR}/frp.tar.gz -C {FRP_DIR} --strip-components=1")
    os.system(f"chmod +x {FRPC_BIN}")

frpc_config = f"""
serverAddr = "{VPS_IP}"
serverPort = 7000
auth.method = "token"
auth.token = "{FRP_TOKEN}"

[[proxies]]
name = "comfyui_colab"
type = "tcp"
localIP = "127.0.0.1"
localPort = 8188
remotePort = 8188
"""
with open(f"{FRP_DIR}/frpc.toml", "w") as f:
    f.write(frpc_config)

print("\n✅ Cell 1 完成！完美基础环境已就绪。后续可直接运行 Cell 6 启动引擎！")
# Out:
# ☁️ 1. 正在挂载 Google Drive (弹窗请点击允许)...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 📥 2. 检查并部署 ComfyUI 核心与管理器...
# ✅ ComfyUI 核心代码已存在。
#
# 📦 3. 安装环境依赖 (取消静默，确保安装成功)...
# Requirement already satisfied: comfyui-frontend-package==1.42.8 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 1)) (1.42.8)
# Requirement already satisfied: comfyui-workflow-templates==0.9.39 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 2)) (0.9.39)
# Requirement already satisfied: comfyui-embedded-docs==0.4.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 4)) (2.10.0+cu128)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 6)) (0.25.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 7)) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 9)) (0.8.2)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 10)) (5.0.0)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 12)) (0.2.1)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 14)) (3.13.3)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 15)) (1.23.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 18)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 19)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 20)) (5.9.5)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 21)) (1.18.4)
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 22)) (2.0.48)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 23)) (3.25.2)
# Requirement already satisfied: av>=14.2.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 24)) (17.0.0)
# Requirement already satisfied: comfy-kitchen>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 25)) (0.2.8)
# Requirement already satisfied: comfy-aimdo>=0.2.12 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 26)) (0.2.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 27)) (2.32.4)
# Requirement already satisfied: simpleeval>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 28)) (1.0.7)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 29)) (1.0.8)
# Requirement already satisfied: kornia>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 32)) (0.8.2)
# Requirement already satisfied: spandrel in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 33)) (0.4.2)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 34)) (2.12.3)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 35)) (2.13.1)
# Requirement already satisfied: PyOpenGL in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 36)) (3.1.10)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from -r /content/ComfyUI/requirements.txt (line 37)) (2.10.0)
# Requirement already satisfied: comfyui-workflow-templates-core==0.3.188 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r /content/ComfyUI/requirements.txt (line 2)) (0.3.188)
# Requirement already satisfied: comfyui-workflow-templates-media-api==0.3.68 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r /content/ComfyUI/requirements.txt (line 2)) (0.3.68)
# Requirement already satisfied: comfyui-workflow-templates-media-video==0.3.68 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r /content/ComfyUI/requirements.txt (line 2)) (0.3.68)
# Requirement already satisfied: comfyui-workflow-templates-media-image==0.3.114 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r /content/ComfyUI/requirements.txt (line 2)) (0.3.114)
# Requirement already satisfied: comfyui-workflow-templates-media-other==0.3.161 in /usr/local/lib/python3.12/dist-packages (from comfyui-workflow-templates==0.9.39->-r /content/ComfyUI/requirements.txt (line 2)) (0.3.161)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/ComfyUI/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r /content/ComfyUI/requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from torchsde->-r /content/ComfyUI/requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (26.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (0.24.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r /content/ComfyUI/requirements.txt (line 14)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r /content/ComfyUI/requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r /content/ComfyUI/requirements.txt (line 14)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r /content/ComfyUI/requirements.txt (line 14)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r /content/ComfyUI/requirements.txt (line 14)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.11.8->-r /content/ComfyUI/requirements.txt (line 14)) (0.4.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl>=1.18.0->-r /content/ComfyUI/requirements.txt (line 15)) (3.11)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->-r /content/ComfyUI/requirements.txt (line 21)) (1.3.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy->-r /content/ComfyUI/requirements.txt (line 22)) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/ComfyUI/requirements.txt (line 27)) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/ComfyUI/requirements.txt (line 27)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r /content/ComfyUI/requirements.txt (line 27)) (2026.2.25)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia>=0.7.1->-r /content/ComfyUI/requirements.txt (line 32)) (0.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r /content/ComfyUI/requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r /content/ComfyUI/requirements.txt (line 34)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->-r /content/ComfyUI/requirements.txt (line 34)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings~=2.0->-r /content/ComfyUI/requirements.txt (line 35)) (1.2.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (0.24.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/ComfyUI/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r /content/ComfyUI/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=4.50.3->-r /content/ComfyUI/requirements.txt (line 10)) (0.1.2)
#
# 🔧 4. 部署 FRP 客户端与配置文件...
#
# ✅ Cell 1 完成！完美基础环境已就绪。后续可直接运行 Cell 6 启动引擎！

# %%
#cell 2
import os

COMFY_DIR = "/kaggle/working/ComfyUI"
MODELS_DIR = f"{COMFY_DIR}/models"
OUTPUT_DIR = f"{COMFY_DIR}/output"

# =================================================================
# 1️⃣ Kaggle 原生数据集（右侧 Data 导入的，0秒挂载，极致读取速度）
# =================================================================
KAGGLE_DATASETS = [
    ("checkpoints", "/kaggle/input/animagine-xl-4-0-comfyui*/*.safetensors"),
    ("checkpoints", "/kaggle/input/datasets/jarredstroman/my-pony-v6-private/*.safetensors"),
    ("loras", "/kaggle/input/datasets/jarredstroman/family-guy-style/*.safetensors"),
]

# =================================================================
# 2️⃣ 外部直链极速下载（用 aria2c 从 C站或 HuggingFace 拉取）
# =================================================================
EXTERNAL_URLS = [
    # 格式: ("文件夹名", "模型直链")
    # ("checkpoints", "https://huggingface.co/.../xxx.safetensors"),
]

print("🧹 1. 清理旧挂载与旧缓存...")
os.system(f"find {MODELS_DIR}/checkpoints -type l -delete")
os.system(f"find {MODELS_DIR}/loras -type l -delete")
os.makedirs(OUTPUT_DIR, exist_ok=True)

print("🔗 2. 正在秒级挂载 Kaggle 本地数据集模型...")
for folder, path in KAGGLE_DATASETS:
    os.makedirs(f"{MODELS_DIR}/{folder}", exist_ok=True)
    os.system(f"ln -sf {path} {MODELS_DIR}/{folder}/")
    print(f"  -> 已挂载 [{folder}]: {path.split('/')[-2]}")

if EXTERNAL_URLS:
    print("\n🚀 3. 部署多线程下载神器 aria2...")
    os.system("apt-get -y install -qq aria2")

    print("📥 4. 正在以最高百兆/秒拉取外部直链模型到本地...")
    for folder, url in EXTERNAL_URLS:
        dest_dir = f"{MODELS_DIR}/{folder}"
        os.makedirs(dest_dir, exist_ok=True)
        print(f"⚡ 极限拉取中: {url.split('/')[-1]}")
        # 16线程并发下载，榨干 Kaggle 万兆带宽
        os.system(f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M '{url}' -d '{dest_dir}'")

print("\n🎉 模型部署完毕！全部基于 Kaggle NVMe 高速本地硬盘！")
print(f"🖼️ 你的图片将极速生成至: {OUTPUT_DIR}")
# Out:
# 🧹 1. 清理旧挂载与旧缓存...
# 🔗 2. 正在秒级挂载 Kaggle 本地数据集模型...
#   -> 已挂载 [checkpoints]: animagine-xl-4-0-comfyui*
#   -> 已挂载 [checkpoints]: my-pony-v6-private
#   -> 已挂载 [loras]: family-guy-style
#
# 🎉 模型部署完毕！全部基于 Kaggle NVMe 高速本地硬盘！
# 🖼️ 你的图片将极速生成至: /kaggle/working/ComfyUI/output

# %%
# gemini3 ltx-2.3
import os

# 安装 aria2
os.system("apt-get -y install -qq aria2")

# 真实下载直链 (把 blob 替换为了 resolve)
MODEL_URL = "https://huggingface.co/Lightricks/LTX-2.3-fp8/resolve/main/ltx-2.3-22b-dev-fp8.safetensors"
MODEL_FILENAME = "c-22b-dev-fp8.safetensors"

DATASET_DIR = "/content/dataset"
UNET_DIR = "/content/ComfyUI/models/unet"
CKPT_DIR = "/content/ComfyUI/models/checkpoints"

# 1. 确保目录存在
os.makedirs(DATASET_DIR, exist_ok=True)
os.makedirs(UNET_DIR, exist_ok=True)
os.makedirs(CKPT_DIR, exist_ok=True)

# 2. 使用 aria2 极速下载
print(f"🚀 开始极速下载 {MODEL_FILENAME}...")
local_model_path = os.path.join(DATASET_DIR, MODEL_FILENAME)

# 极速下载指令
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M '{MODEL_URL}' -d '{DATASET_DIR}' -o '{MODEL_FILENAME}'

# 3. 挂载 (软链接) 到 ComfyUI 节点
print("🔗 正在挂载模型到 ComfyUI...")
unet_link = os.path.join(UNET_DIR, MODEL_FILENAME)
ckpt_link = os.path.join(CKPT_DIR, MODEL_FILENAME)

# 强制创建软链接
os.system(f"ln -sf {local_model_path} {unet_link}")
os.system(f"ln -sf {local_model_path} {ckpt_link}")

print(f"✅ 模型已成功挂载！")
print(f"📍 UNET 路径: {unet_link}")
print(f"📍 CKPT 路径: {ckpt_link}")
# Out:
# 🚀 开始极速下载 c-22b-dev-fp8.safetensors...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9aafc4|OK  |       0B/s|/content/dataset/c-22b-dev-fp8.safetensors
#
# Status Legend:
# (OK):download completed.
# 🔗 正在挂载模型到 ComfyUI...
# ✅ 模型已成功挂载！
# 📍 UNET 路径: /content/ComfyUI/models/unet/c-22b-dev-fp8.safetensors
# 📍 CKPT 路径: /content/ComfyUI/models/checkpoints/c-22b-dev-fp8.safetensors

# %%
# cell 3 下载ae,clip_l,t5xxl_fp16模型
import os
from google.colab import userdata

# 1. 从 Colab Secrets 安全读取 HF Token
try:
    os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')
    print("✅ 成功从 Secrets 读取 HF_TOKEN！")
except userdata.SecretNotFoundError:
    print("❌ 找不到 Token！请点击左侧 🔑 图标添加 HF_TOKEN，并允许 Notebook 访问。")

# 2. 安装多线程下载神器 aria2
# !apt -y install -qq aria2

# 3. 确保目录存在
# !mkdir -p /content/ComfyUI/models/vae/
# !mkdir -p /content/ComfyUI/models/clip/

# 4. 极速下载（带上 Token 鉴权头，彻底防拦截）
print("🚀 开始极速下载 VAE (ae.safetensors)...")
# !aria2c --header="Authorization: Bearer $HF_TOKEN" --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/black-forest-labs/FLUX.1-schnell/resolve/main/ae.safetensors -d /content/ComfyUI/models/vae -o ae.safetensors

print("🚀 开始极速下载 CLIP-L (clip_l.safetensors)...")
# !aria2c --header="Authorization: Bearer $HF_TOKEN" --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/clip_l.safetensors -d /content/ComfyUI/models/clip -o clip_l.safetensors

print("🚀 开始极速下载满血版 T5XXL (t5xxl_fp16.safetensors，约 9.8GB)...")
# !aria2c --header="Authorization: Bearer $HF_TOKEN" --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp16.safetensors -d /content/ComfyUI/models/clip -o t5xxl_fp16.safetensors

print("🎉 所有 Flux 必需的齿轮已带 Token 鉴权安全下载完毕！")
# Out:
# ✅ 成功从 Secrets 读取 HF_TOKEN！
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# 🚀 开始极速下载 VAE (ae.safetensors)...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 491e05|OK  |   355MiB/s|/content/ComfyUI/models/vae/ae.safetensors
#
# Status Legend:
# (OK):download completed.
# 🚀 开始极速下载 CLIP-L (clip_l.safetensors)...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e73e0b|OK  |   324MiB/s|/content/ComfyUI/models/clip/clip_l.safetensors
#
# Status Legend:
# (OK):download completed.
# 🚀 开始极速下载满血版 T5XXL (t5xxl_fp16.safetensors，约 9.8GB)...

# %%
# cell4 从kaggle中拉取flux1-schnell.safetensors，并放置在两个目录下
import os
from google.colab import userdata

# 1. 从 Colab Secrets 安全读取 Kaggle Token
try:
    os.environ["KAGGLE_API_TOKEN"] = userdata.get('KAGGLE_API_TOKEN')
    print("✅ 成功从 Colab Secrets 读取 API Token！")
except userdata.SecretNotFoundError:
    print("❌ 找不到 Token！请点击左侧 🔑 图标添加名为 KAGGLE_API_TOKEN 的密钥，并允许 Notebook 访问。")

# 2. 升级 Kaggle CLI 确保支持新版 Token
# !pip install -q -U kaggle

# 3. 创建接收目录并下载
# !mkdir -p /content/dataset
print("⏳ 正在从 Kaggle 拉取 Flux 模型...")
# !kaggle datasets download -d jarredstroman/flux-2d-assets-2026-v12 -p /content/dataset --unzip

# 4. 创建 ComfyUI 模型目录
# !mkdir -p /content/ComfyUI/models/unet/
# !mkdir -p /content/ComfyUI/models/checkpoints/


# 5. 建立软链接到 ComfyUI 目录
# !ln -sf /content/dataset/flux1-schnell.safetensors /content/ComfyUI/models/unet/flux1-schnell.safetensors
# !ln -s /content/dataset/flux1-schnell.safetensors /content/ComfyUI/models/checkpoints/flux1-schnell.safetensors

print("✅ 模型已成功挂载到 ComfyUI！")

# %%
# cell5 最终精简稳定版
#============================================================

import os
import shutil
from pathlib import Path
from huggingface_hub import HfApi, hf_hub_download

# ----------------------------
# 1) 安装基础依赖
# ----------------------------
os.system("pip install -q -U huggingface_hub")

# ----------------------------
# 2) 安装自定义节点
# ----------------------------
CUSTOM_NODES_DIR = "/content/ComfyUI/custom_nodes"
os.makedirs(CUSTOM_NODES_DIR, exist_ok=True)

plugins = [
    "https://github.com/cubiq/ComfyUI_IPAdapter_plus.git",
    "https://github.com/Fannovel16/comfyui_controlnet_aux.git",
    "https://github.com/rgthree/rgthree-comfy.git",
]

for url in plugins:
    repo_name = url.split("/")[-1].replace(".git", "")
    repo_path = os.path.join(CUSTOM_NODES_DIR, repo_name)
    if not os.path.exists(repo_path):
        print(f"⬇️ 正在克隆插件: {repo_name} ...")
        os.system(f"git clone -q {url} {repo_path}")

    req_file = os.path.join(repo_path, "requirements.txt")
    if os.path.exists(req_file):
        print(f"📦 正在安装依赖: {repo_name} ...")
        os.system(f"pip install -q -r {req_file}")

# ----------------------------
# 3) 创建目录
# ----------------------------
for d in [
    "unet", "clip", "vae", "ipadapter", "clip_vision",
    "controlnet", "checkpoints", "loras", "xlabs/ipadapters"
]:
    os.makedirs(f"/content/ComfyUI/models/{d}", exist_ok=True)

os.makedirs("/content/dataset", exist_ok=True)

# ----------------------------
# 4) 安全软链
# ----------------------------
def safe_symlink(src, dst, desc):
    try:
        src = Path(src)
        dst = Path(dst)

        if src.exists() and dst.exists():
            try:
                if src.resolve() == dst.resolve():
                    print(f"ℹ️ {desc} 已在正确位置，跳过：{dst}")
                    return
            except Exception:
                pass

        if dst.is_symlink() or dst.exists():
            if dst.is_dir() and not dst.is_symlink():
                shutil.rmtree(dst)
            else:
                dst.unlink()

        if src.exists():
            dst.parent.mkdir(parents=True, exist_ok=True)
            os.symlink(str(src), str(dst))
            print(f"✅ {desc}: {src} -> {dst}")
        else:
            print(f"⚠️ 未找到 {desc} 源文件：{src}")
    except Exception as e:
        print(f"❌ {desc} 处理失败：{e}")

# ----------------------------
# 5) Flux 主模型挂载
# ----------------------------
safe_symlink(
    "/content/dataset/flux1-schnell.safetensors",
    "/content/ComfyUI/models/unet/flux1-schnell.safetensors",
    "Flux 主模型 flux1-schnell.safetensors"
)

# ----------------------------
# 6) CLIP Vision 下载/挂载
# ----------------------------
CLIP_VISION_REPO = "shiertier/clip_vision"
CLIP_VISION_FILE = "CLIP-ViT-bigG-14-laion2B-39B-b160k.safetensors"
CLIP_VISION_LOCAL = f"/content/dataset/{CLIP_VISION_FILE}"
CLIP_VISION_DST = f"/content/ComfyUI/models/clip_vision/{CLIP_VISION_FILE}"

if not os.path.exists(CLIP_VISION_LOCAL):
    print("⬇️ 开始下载 CLIP Vision ...")
    downloaded = hf_hub_download(
        repo_id=CLIP_VISION_REPO,
        filename=CLIP_VISION_FILE,
        local_dir="/content/dataset"
    )
    print(f"✅ CLIP Vision 下载完成：{downloaded}")

safe_symlink(CLIP_VISION_LOCAL, CLIP_VISION_DST, "CLIP Vision 模型")

# ----------------------------
# 7) 自动发现 Flux IPAdapter 仓库文件并下载
# ----------------------------
api = HfApi()
repo_id = "XLabs-AI/flux-ip-adapter"

print(f"🔎 正在列出仓库文件：{repo_id}")
files = api.list_repo_files(repo_id=repo_id)

safetensor_files = [f for f in files if f.endswith(".safetensors")]

if not safetensor_files:
    print(f"⚠️ 在 {repo_id} 中没有找到 .safetensors 文件")
else:
    chosen_file = None
    for candidate in safetensor_files:
        name = candidate.lower()
        if "adapter" in name:
            chosen_file = candidate
            break
    if chosen_file is None:
        chosen_file = safetensor_files[0]

    print(f"⬇️ 选择下载文件：{chosen_file}")
    local_download = hf_hub_download(
        repo_id=repo_id,
        filename=chosen_file,
        local_dir="/content/dataset"
    )
    print(f"✅ 下载完成：{local_download}")

    FLUX_IPADAPTER_DST = f"/content/ComfyUI/models/xlabs/ipadapters/{Path(chosen_file).name}"
    os.makedirs(os.path.dirname(FLUX_IPADAPTER_DST), exist_ok=True)

    if os.path.exists(FLUX_IPADAPTER_DST) or os.path.islink(FLUX_IPADAPTER_DST):
        try:
            os.remove(FLUX_IPADAPTER_DST)
        except:
            pass

    os.symlink(local_download, FLUX_IPADAPTER_DST)
    print(f"✅ Flux IPAdapter 权重: {local_download} -> {FLUX_IPADAPTER_DST}")

# ----------------------------
# 8) 旧 checkpoints 检查
# ----------------------------
old_ckpt = "/content/ComfyUI/models/checkpoints/flux1-schnell.safetensors"
if os.path.exists(old_ckpt):
    print("⚠️ 检测到旧位置的 Flux 模型：/content/ComfyUI/models/checkpoints/flux1-schnell.safetensors")
    print("   建议后续工作流使用 /content/ComfyUI/models/unet/ 下的模型。")

# ----------------------------
# 9) 输出当前目录状态
# ----------------------------
print("\n📁 当前 /content/ComfyUI/models 文件列表：")
os.system("find /content/ComfyUI/models -maxdepth 3 -type f -o -type l | sort")

print("\n✅ 处理完成。")
print("⚠️ 请重启 ComfyUI，再重新加载工作流。")

# %%
# cell6 跑日常，前面的不需要跑，只需跑一次
import os, time, subprocess, socket

COMFY_DIR = "/content/ComfyUI"
FRP_DIR = "/content/frp"
FRPC_BIN = f"{FRP_DIR}/frpc"
VPS_IP = "34.153.197.18"

# ==================================================
# 🛒 应用商店开关 (ComfyUI-Manager)
# False = 日常极速跑图 (屏蔽 Manager，极速启动)
# True  = 需要安装新插件时打开 (恢复慢速下载缓存)
# ==================================================
ENABLE_MANAGER = False

print("🛑 1. 秒杀旧进程，释放端口...")
os.system("pkill -f 'main.py'")
os.system("pkill -f frpc")
time.sleep(1)

print(f"🎛️ 2. 处理 Manager 状态 (当前: {'开启' if ENABLE_MANAGER else '极致屏蔽'})...")
MANAGER_DIR = f"{COMFY_DIR}/custom_nodes/ComfyUI-Manager"
HIDDEN_MANAGER_DIR = f"{COMFY_DIR}/ComfyUI-Manager_hidden"

if ENABLE_MANAGER:
    if os.path.exists(HIDDEN_MANAGER_DIR):
        os.rename(HIDDEN_MANAGER_DIR, MANAGER_DIR)
else:
    if os.path.exists(MANAGER_DIR):
        os.rename(MANAGER_DIR, HIDDEN_MANAGER_DIR)

print("🚀 3. 极速启动 ComfyUI 主引擎...")
# 官方已移除 --normalvram 参数，直接启动即可
comfy = subprocess.Popen(["python3", "main.py"], cwd=COMFY_DIR)

print("⏳ 4. 等待引擎点火...")
for _ in range(60):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        if s.connect_ex(("127.0.0.1", 8188)) == 0:
            break
    time.sleep(1)

print("🌐 5. 端口就绪！唤醒 FRP 隧道...")
frpc = subprocess.Popen([FRPC_BIN, "-c", f"{FRP_DIR}/frpc.toml"])

print("\n" + "="*50)
print(f"🎉 Colab 引擎已极速拉起！(应用商店: {'已加载' if ENABLE_MANAGER else '已隐藏'})")
print(f"👉 请刷新网页: http://{VPS_IP}:8188")
print("="*50 + "\n")

comfy.wait()
# Out:
# 🛑 1. 秒杀旧进程，释放端口...
# 🎛️ 2. 处理 Manager 状态 (当前: 极致屏蔽)...
# 🚀 3. 极速启动 ComfyUI 主引擎...
# ⏳ 4. 等待引擎点火...
# 🌐 5. 端口就绪！唤醒 FRP 隧道...
#
# ==================================================
# 🎉 Colab 引擎已极速拉起！(应用商店: 已隐藏)
# 👉 请刷新网页: http://34.153.197.18:8188
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_37112/1966829779.py in <cell line: 0>()
#      49 print("="*50 + "\n")
#      50
# ---> 51 comfy.wait()
#
# /usr/lib/python3.12/subprocess.py in wait(self, timeout)
#    1262             endtime = _time() + timeout
#    1263         try:
# -> 1264             return self._wait(timeout=timeout)
#    1265         except KeyboardInterrupt:
#    1266             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _wait(self, timeout)
#    2051                         if self.returncode is not None:
#    2052                             break  # Another thread waited.
# -> 2053                         (pid, sts) = self._try_wait(0)
#    2054                         # Check the pid and loop as waitpid has been known to
#    2055                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.12/subprocess.py in _try_wait(self, wait_flags)
#    2009             """All callers to this function MUST hold self._waitpid_lock."""
#    2010             try:
# -> 2011                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012             except ChildProcessError:
#    2013                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
# 1. 自动创建缺失的专用模型文件夹
# !mkdir -p /content/ComfyUI/models/checkpoints
# !mkdir -p /content/ComfyUI/models/latent_upscale_models
# !mkdir -p /content/ComfyUI/models/loras
# !mkdir -p /content/ComfyUI/models/text_encoders

print("文件夹准备完毕，开始下载模型（支持断点续传）...")

# 2. 下载主模型 Checkpoint (约 27GB，耗时最长)
# !wget -c https://huggingface.co/Lightricks/LTX-2.3-fp8/resolve/main/ltx-2.3-22b-dev-fp8.safetensors -P /content/ComfyUI/models/checkpoints/

# 3. 下载 Latent Upscaler 放大模型 (约 950MB)
# !wget -c https://huggingface.co/Lightricks/LTX-2.3/resolve/main/ltx-2.3-spatial-upscaler-x2-1.1.safetensors -P /content/ComfyUI/models/latent_upscale_models/

# 4. 下载 Loras (2 个文件)
# !wget -c https://huggingface.co/Lightricks/LTX-2.3/resolve/main/ltx-2.3-22b-distilled-lora-384.safetensors -P /content/ComfyUI/models/loras/
# !wget -c https://huggingface.co/Comfy-Org/ltx-2/resolve/main/split_files/loras/gemma-3-12b-it-abliterated_lora_rank64_bf16.safetensors -P /content/ComfyUI/models/loras/

# 5. 下载 Text Encoder 文本编码器
# !wget -c https://huggingface.co/Comfy-Org/ltx-2/resolve/main/split_files/text_encoders/gemma_3_12B_it_fp4_mixed.safetensors -P /content/ComfyUI/models/text_encoders/

print("✅ 所有模型下载指令执行完毕！")
# Out:
# 文件夹准备完毕，开始下载模型（支持断点续传）...
# --2026-03-28 15:32:33--  https://huggingface.co/Lightricks/LTX-2.3-fp8/resolve/main/ltx-2.3-22b-dev-fp8.safetensors
# Resolving huggingface.co (huggingface.co)... 13.249.74.25, 13.249.74.3, 13.249.74.12, ...
# Connecting to huggingface.co (huggingface.co)|13.249.74.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cas-bridge.xethub.hf.co/xet-bridge-us